# %%
# body内容从本地文件中获取
    # 打开图片文件
import base64
f = open(r'test.png', 'rb')
img_base64 = base64.b64encode(f.read()).decode()

# body内容
params = {"imageContent": img_base64}
print(params)
# Out:
# {'imageContent': '...'}
